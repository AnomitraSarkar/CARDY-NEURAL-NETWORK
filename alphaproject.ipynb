# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
import matplotlib.image as img

# %%
img1 = img.imread('image.png',0)
plt.imshow(img1)

# %%
img = img1[:,:,:3]
# plt.imshow(img)
# imgcpy = img
# imgcpy = imgcpy.reshape(863* 895* 3)
# imgcpy = im
# imgcpy = imgcpy.reshape((863,895, 3))
img.shape
# Out:
# (863, 895, 4)

# %%
img.shape
inputter = np.zeros((img.shape))
inputter.shape

img = img.reshape((863*895,4))
inputter = inputter.reshape((863*895,4))

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(4,activation="leaky_relu"),
    tf.keras.layers.Dense(100,activation="leaky_relu"),
    tf.keras.layers.Dense(100,activation="leaky_relu"),
    tf.keras.layers.Dense(4,activation="leaky_relu"),
    tf.keras.layers.Softmax()
])

# %%
model.compile(
    optimizer = "adam",
    loss = tf.keras.losses.BinaryCrossentropy,
    metrics = ['accuracy']
)

# %%
inputter = inputter.reshape((863*895,4))

# %%
model.fit(img,img,epochs = 10)
# Out:
# Epoch 1/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 37s 1ms/step - accuracy: 0.8504 - loss: 0.3102
# Epoch 2/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 35s 1ms/step - accuracy: 0.8498 - loss: 0.3029
# Epoch 3/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 32s 1ms/step - accuracy: 0.8497 - loss: 0.3029
# Epoch 4/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 28s 1ms/step - accuracy: 0.8504 - loss: 0.3027
# Epoch 5/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 34s 1ms/step - accuracy: 0.8506 - loss: 0.3028
# Epoch 6/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 36s 1ms/step - accuracy: 0.8505 - loss: 0.3027
# Epoch 7/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 33s 1ms/step - accuracy: 0.8504 - loss: 0.3029
# Epoch 8/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 33s 1ms/step - accuracy: 0.8506 - loss: 0.3030
# Epoch 9/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 38s 2ms/step - accuracy: 0.8508 - loss: 0.3028
# Epoch 10/10
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 51s 2ms/step - accuracy: 0.8501 - loss: 0.3028

# %%
predictor = model.predict(img)
# Out:
# 24138/24138 ━━━━━━━━━━━━━━━━━━━━ 37s 2ms/step

# %%
predictor.shape
# Out:
# (772385, 4)

# %%
predictor = predictor.reshape(863,895,4)

# %%
plt.imshow(predictor[:,:,:3])

# %%
img[100]
# Out:
# array([1.       , 1.       , 0.7882353, 1.       ], dtype=float32)
